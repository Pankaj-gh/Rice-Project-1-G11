# %%
import pandas as pd
import os

# %%
file_path = os.path.join("Resources","us-counties.csv")
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
df_new=df.dropna()

# %%
df_new.isnull().sum()
# Out:
# date      0
# county    0
# state     0
# fips      0
# cases     0
# deaths    0
# dtype: int64

# %%
df_new.shape
# Out:
# (510107, 6)

# %%
df_new_date=df_new[df_new['date']=='2020-09-08']

# %%
df_new_date.head()
# Out:
#               date   county    state    fips  cases  deaths
# 511829  2020-09-08  Autauga  Alabama  1001.0   1508      24
# 511830  2020-09-08  Baldwin  Alabama  1003.0   4757      46
# 511831  2020-09-08  Barbour  Alabama  1005.0    778       7
# 511832  2020-09-08     Bibb  Alabama  1007.0    589       9
# 511833  2020-09-08   Blount  Alabama  1009.0   1390      12

# %%
df_new_date.shape
# Out:
# (3203, 6)

# %%
df_new_date['fips'].nunique()
# Out:
# 3203

# %%
df_sorted=df_new_date.sort_values((['cases']),ascending=False)

# %%
df_100=df_sorted.head(100)

# %%
df_100.head()
# Out:
#               date       county       state     fips   cases  deaths
# 512032  2020-09-08  Los Angeles  California   6037.0  249241    6036
# 512191  2020-09-08   Miami-Dade     Florida  12086.0  162025    2666
# 511930  2020-09-08     Maricopa     Arizona   4013.0  136040    3093
# 512441  2020-09-08         Cook    Illinois  17031.0  132079    5098
# 514539  2020-09-08       Harris       Texas  48201.0  112039    2342

# %%
df_100.reset_index(drop=True,inplace=True)

# %%
df_100.head()
# Out:
#          date       county       state     fips   cases  deaths
# 0  2020-09-08  Los Angeles  California   6037.0  249241    6036
# 1  2020-09-08   Miami-Dade     Florida  12086.0  162025    2666
# 2  2020-09-08     Maricopa     Arizona   4013.0  136040    3093
# 3  2020-09-08         Cook    Illinois  17031.0  132079    5098
# 4  2020-09-08       Harris       Texas  48201.0  112039    2342

# %%
df_100.shape
# Out:
# (100, 6)

# %%
df_100.head()
# Out:
#          date       county       state     fips   cases  deaths
# 0  2020-09-08  Los Angeles  California   6037.0  249241    6036
# 1  2020-09-08   Miami-Dade     Florida  12086.0  162025    2666
# 2  2020-09-08     Maricopa     Arizona   4013.0  136040    3093
# 3  2020-09-08         Cook    Illinois  17031.0  132079    5098
# 4  2020-09-08       Harris       Texas  48201.0  112039    2342

# %%
pt_df_top5=df_100.head()

# %%
#Dropping Deaths Column and isolating top 5 affected areas from the rest
pt_df_top5.drop(['deaths'],axis=1,inplace=True)
# Out:
# C:\Users\Pankaj\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
pt_df_top5
# Out:
#          date       county       state     fips   cases
# 0  2020-09-08  Los Angeles  California   6037.0  249241
# 1  2020-09-08   Miami-Dade     Florida  12086.0  162025
# 2  2020-09-08     Maricopa     Arizona   4013.0  136040
# 3  2020-09-08         Cook    Illinois  17031.0  132079
# 4  2020-09-08       Harris       Texas  48201.0  112039

# %%
import requests
from config import pt_gkey
import gmaps

# %%
target='Los Angeles, California'

# %%
url='https://maps.googleapis.com/maps/api/geocode/json?address={}&key={}'.format(target,pt_gkey)

# %%
#geo_data=requests.get(url).json()

# %%
#geo_data

# %%
#geo_data['results']

# %%
#geo_data['results'][0]['geometry']['location']['lat']

# %%
#geo_data['results'][0]['geometry']['location']['lng']

# %%
for index,row in pt_df_top5.iterrows():
    county=row['county']
    state=row['state']
    target=f'{county},{state}'
    url='https://maps.googleapis.com/maps/api/geocode/json?address={}&key={}'.format(target,pt_gkey)
    geo_data=requests.get(url).json()
    pt_df_top5.loc[index,'Latitude'] = geo_data['results'][0]['geometry']['location']['lat']
    pt_df_top5.loc[index,'Longitude'] = geo_data['results'][0]['geometry']['location']['lng']
# Out:
# C:\Users\Pankaj\Anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Pankaj\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
pt_df_top5
# Out:
#          date       county       state     fips   cases   Latitude   Longitude
# 0  2020-09-08  Los Angeles  California   6037.0  249241  34.052234 -118.243685
# 1  2020-09-08   Miami-Dade     Florida  12086.0  162025  25.551603  -80.632692
# 2  2020-09-08     Maricopa     Arizona   4013.0  136040  33.058106 -112.047642
# 3  2020-09-08         Cook    Illinois  17031.0  132079  41.737659  -87.697554
# 4  2020-09-08       Harris       Texas  48201.0  112039  29.775182  -95.310250

# %%
pt_locations =pt_df_top5[['Latitude','Longitude']]
pt_cases=pt_df_top5['cases'].astype(float)
pt_maxx=pt_df_top5['cases'].max()
pt_maxx=pt_maxx.astype(float)

# %%
fig=gmaps.figure()
heat_layer=gmaps.heatmap_layer(pt_locations,weights=pt_cases,dissipating=False,max_intensity=pt_maxx,point_radius=0.9)

# %%
fig.add_layer(heat_layer)

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>County</dt><dd>{county}</dd>
<dt>State</dt><dd>{state}</dd>
<dt>Cases</dt><dd>{cases}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
covid_info = [info_box_template.format(**row) for index, row in pt_df_top5.iterrows()]
locations = pt_df_top5[["Latitude", "Longitude"]]

# %%
marker_layer=gmaps.marker_layer(locations,info_box_content=covid_info)

# %%
fig.add_layer(marker_layer)

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
pt_path=os.path.join('Resources','mask-use-by-county.csv')

# %%
pt_df=pd.read_csv(pt_path)

# %%
pt_df.shape
# Out:
# (3142, 6)

# %%
pt_df.head()
# Out:
#    COUNTYFP  NEVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS
# 0      1001  0.053   0.074      0.134       0.295   0.444
# 1      1003  0.083   0.059      0.098       0.323   0.436
# 2      1005  0.067   0.121      0.120       0.201   0.491
# 3      1007  0.020   0.034      0.096       0.278   0.572
# 4      1009  0.053   0.114      0.180       0.194   0.459

# %%
pt_df.rename(columns={'COUNTYFP':'fips'},inplace=True)

# %%
pt_merged=pd.merge(df_new_date,pt_df,on='fips')

# %%
pt_merged=pt_merged.sort_values(['cases'],ascending=False)

# %%
pt_merged=pt_merged.head(100)

# %%
pt_merged
# Out:
#             date           county           state     fips   cases  deaths  \
# 201   2020-09-08      Los Angeles      California   6037.0  249241    6036
# 358   2020-09-08       Miami-Dade         Florida  12086.0  162025    2666
# 100   2020-09-08         Maricopa         Arizona   4013.0  136040    3093
# 605   2020-09-08             Cook        Illinois  17031.0  132079    5098
# 2604  2020-09-08           Harris           Texas  48201.0  112039    2342
# 2560  2020-09-08           Dallas           Texas  48113.0   77326    1011
# 321   2020-09-08          Broward         Florida  12011.0   73556    1234
# 1739  2020-09-08            Clark          Nevada  32003.0   61543    1206
# 215   2020-09-08        Riverside      California   6065.0   54572    1075
# 212   2020-09-08           Orange      California   6059.0   51016    1056
# 218   2020-09-08   San Bernardino      California   6071.0   49691     765
# 2519  2020-09-08            Bexar           Texas  48029.0   47748    1167
# 1862  2020-09-08          Suffolk        New York  36103.0   45356    2006
# 1843  2020-09-08           Nassau        New York  36059.0   45294    2199
# 365   2020-09-08       Palm Beach         Florida  12099.0   43307    1170
EVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS
# 201   0.021   0.013      0.049       0.131   0.786
# 358   0.032   0.023      0.060       0.128   0.756
# 100   0.023   0.025      0.059       0.158   0.734
# 605   0.023   0.021      0.072       0.162   0.722
# 2604  0.019   0.024      0.069       0.152   0.736
# 2560  0.024   0.019      0.059       0.141   0.757
# 321   0.026   0.023      0.043       0.117   0.791
# 1739  0.027   0.032      0.054       0.145   0.742
# 215   0.026   0.014      0.041       0.116   0.803
# 212   0.023   0.021      0.046       0.156   0.754
# 218   0.027   0.022      0.048       0.134   0.768
# 2519  0.015   0.016      0.057       0.090   0.822
# 1862  0.040   0.019      0.053       0.106   0.782
# 1843  0.017   0.018      0.043       0.142   0.779
# 365   0.030   0.020      0.050       0.116   0.784
# 2721  0.023   0.034      0.077       0.144   0.722
# 219   0.017   0.023      0.034       0.126   0.800
# 343   0.023   0.031      0.069       0.155   0.722
# 1870  0.025   0.018      0.044       0.115   0.798
# 363   0.020   0.020      0.072       0.164   0.724
# 2276  0.023   0.012      0.051       0.120   0.794
# 1307  0.046   0.032      0.075       0.156   0.690
# 197   0.022   0.028      0.105       0.177   0.668
# 2611  0.055   0.003      0.033       0.084   0.826
# 2488  0.034   0.025      0.105       0.184   0.653
# 330   0.049   0.042      0.086       0.194   0.629
# 1204  0.087   0.034      0.064       0.094   0.720
# 2728  0.015   0.008      0.024       0.158   0.795
# 2428  0.020   0.037      0.086       0.181   0.677
# 1932  0.029   0.037      0.075       0.166   0.694
# ...     ...     ...        ...         ...     ...
# 1604  0.118   0.199      0.146       0.296   0.240
# 558   0.186   0.030      0.047       0.098   0.639
# 2717  0.032   0.077      0.067       0.252   0.572
# 1267  0.006   0.071      0.129       0.277   0.518
# 2807  0.099   0.045      0.121       0.165   0.570
# 918   0.135   0.131      0.181       0.229   0.323
# 2581  0.045   0.101      0.230       0.147   0.477
# 1610  0.134   0.181      0.168       0.246   0.271
# 268   0.043   0.050      0.117       0.271   0.519
# 2723  0.021   0.061      0.167       0.154   0.597
# 3110  0.169   0.191      0.177       0.222   0.241
# 1670  0.093   0.147      0.138       0.267   0.355
# 1642  0.122   0.188      0.160       0.259   0.270
# 1601  0.172   0.244      0.186       0.269   0.129
# 258   0.052   0.039      0.066       0.252   0.591
# 1794  0.057   0.152      0.062       0.115   0.614
# 1650  0.249   0.128      0.134       0.216   0.272
# 1622  0.097   0.278      0.119       0.183   0.323
# 1735  0.162   0.084      0.155       0.201   0.399
# 1687  0.085   0.162      0.190       0.263   0.301
# 2374  0.105   0.068      0.145       0.235   0.446
# 1628  0.193   0.240      0.106       0.188   0.273
# 2782  0.068   0.129      0.114       0.269   0.420
# 1701  0.193   0.084      0.129       0.276   0.318
# 184   0.025   0.085      0.088       0.190   0.612
# 1649  0.144   0.135      0.117       0.248   0.356
# 1630  0.101   0.270      0.171       0.283   0.176
# 907   0.061   0.050      0.295       0.282   0.312
# 1695  0.124   0.090      0.183       0.273   0.331
# 959   0.128   0.174      0.209       0.220   0.268
#
# [3120 rows x 11 columns]

# %%
rar=pt_merged['NEVER'] + pt_merged['RARELY']+pt_merged['SOMETIMES']+pt_merged['FREQUENTLY']
cases=pt_merged['cases']

# %%
import matplotlib.pyplot as plt
plt.scatter(rar,cases)
plt.show()

# %%
import scipy.stats as sts

# %%
corr=sts.pearsonr(rar,cases)
corr
# Out:
# (-0.23976122193996305, 4.875628101380193e-42)
